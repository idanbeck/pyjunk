# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# This notebook is testing the JIT image loader

# %%
# Single image JIT loading testing

import repos.pyjunk.junktools as junktools
from repos.pyjunk.junktools.image import image

# testImage = image('SimpleSensor_RGB_test.png', fJITLoading=False)
# testImage.square(max_size=64)
# testImage.whiten(fZCA=False)
# testImage.visualize()

testImageJIT = image('SimpleSensor_RGB_test.png', fJITLoading=True)
testImageJIT.square(max_size=64)
testImageJIT.whiten(fZCA=False)
testImageJIT.visualize()
testImageJIT.visualize()
# Out:
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded

# %%
# %load_ext autoreload
# %autoreload 2

# Test out the above for a frameset

from repos.pyjunk.junktools.frameset import frameset
from repos.pyjunk.solvers.SimpleTorchSolver import SimpleTorchSolver
from repos.pyjunk.models.SimpleMLP import SimpleMLP

strFramesetName = 'spheres'
img_size = 32
batch_size = 2
num_frames = 2

# spheres = frameset(strFramesetName, num_frames=num_frames, fJITLoading=False)
# spheres.square(max_size=img_size)
# spheres.whiten(fZCA=False)
# spheres.Print()
# spheres.visualize()

spheres = frameset(strFramesetName, num_frames=num_frames, fJITLoading=True, fVerbose=True)
spheres.square(max_size=img_size)
spheres.whiten(fZCA=False)
spheres.Print()
spheres.visualize()
spheres.visualize()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading frames 2 to 4
# Loading: frame 2
# Loading: frame 3
# Squaring frame 2
# Squaring frame 3
# Whitening frame 2
# Whitening frame 3
# Frameset: spheres, 2 frames with 10 channels JIT enabled
# Visualizing frame spheres: 2
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# Visualizing frame spheres: 3
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# Visualizing frame spheres: 2
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# /src/repos/pyjunk/junktools/image.py:123: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# Visualizing frame spheres: 3
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded
# visualizing image states.not_loaded
# loading image states.loading
# squaring image
# whitening image
# image states.loaded
# unloading image states.loaded

# %%
# %load_ext autoreload
# %autoreload 2

# Test out loading a frameset, applying transformations, and then saving to a new 
# dataset.  Then trying to load it again

from repos.pyjunk.junktools.frameset import frameset
from repos.pyjunk.solvers.SimpleTorchSolver import SimpleTorchSolver
from repos.pyjunk.models.SimpleMLP import SimpleMLP

strFramesetName = 'spheres'
strNewFramesetName = 'spheres_32_wht'
img_size = 32
num_frames = 10

# Load the original dataset

spheres = frameset(strFramesetName, num_frames=num_frames, fJITLoading=True, fVerbose=False)
spheres.square(max_size=img_size)
spheres.whiten(fZCA=False)
spheres.Print()
#spheres.visualize()

# Save the frameset to a new frameset
spheres.save_to_new_frameset(strNewFramesetName)

# load the new frameset and visualize it
spheresNew = frameset(strNewFramesetName, num_frames=num_frames, fJITLoading=False, fVerbose=False)
spheresNew.Print()
spheresNew.visualize()
# Out:
# Loading frames 2 to 12
# Frameset: spheres, 10 frames with 10 channels JIT enabled
# repos/pyjunk/data/frames/spheres_32_wht/spheres_32_wht.json
# Saving frames 2 to 12
# Loading frames 2 to 12
# Frameset: spheres_32_wht, 10 frames with 10 channels JIT disabled
# Visualizing frame spheres_32_wht: 2
# Visualizing frame spheres_32_wht: 3
# Visualizing frame spheres_32_wht: 4
# Visualizing frame spheres_32_wht: 5
# /src/repos/pyjunk/junktools/image.py:156: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# Visualizing frame spheres_32_wht: 6
# Visualizing frame spheres_32_wht: 7
# Visualizing frame spheres_32_wht: 8
# Visualizing frame spheres_32_wht: 9
# Visualizing frame spheres_32_wht: 10
# Visualizing frame spheres_32_wht: 11

# %%
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-3-8ac32b0b2225> in <module>
#       1 # Save the frameset to a new frameset
# ----> 2 spheres.save_to_new_frameset(strNewFramesetName)
#       3
#       4 # # load the new frameset and visualize it
#       5 # spheresNew = frameset(strNewFramesetName, num_frames=num_frames, fJITLoading=True, fVerbose=True)
#
# /src/repos/pyjunk/junktools/frameset.py in save_to_new_frameset(self, strNewFramesetName, strExtension)
#      67
#      68         # Save the JSON file to a new folder named as the respective new frameset
# ---> 69         strJsonPathname, strPath = utils.SaveNewFramesetJSON(strNewFramesetName, jsonData)
#      70         print(strJsonPathname)
#      71
#
# /src/repos/pyjunk/junktools/utils.py in SaveNewFramesetJSON(strFramesetName, jsonData)
#     123
#     124     if not os.path.exists(strPath):
# --> 125         os.makedirs(strPath)
#     126
#     127     with open(join(strPath, strFramesetFilename), 'w') as framesetJSONFile:
#
# /usr/lib/python3.6/os.py in makedirs(name, mode, exist_ok)
#     218             return
#     219     try:
# --> 220         mkdir(name, mode)
#     221     except OSError:
#     222         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: 'repos/pyjunk/data/frames/spheres_32_wht'
